# %% [markdown]
# <a href="https://colab.research.google.com/github/tayyba6/ML_Internship/blob/main/work/notebooks/w02_ml_task_framing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# *Classification, clustering, ranking, or scoring — which one, and why?*

# %% [markdown]
# **Task type: Ranking**
#
# My lane is a ranking problem because the goal is to prioritize pages for content review. Instead of only predicting whether a page needs attention, the model would order pages from higher to lower review priority. This gives a reviewer a practical queue so they can start with the pages that appear most likely to need attention.

# %% [markdown]
# ## 2. Target or proxy
#
# *What would you predict? Where does that label come from — observed outcome or a defined rule?*

# %% [markdown]
# **Target/proxy: observed negative trend**
#
# I will use an observed negative trend as a proxy for review priority. A page with a negative `trend_pct` is treated as a potential review candidate because its measured performance has declined. This is an observed proxy, not proof that the page needs a refresh or that a refresh will improve performance. The model will use other page-level signals to rank pages, and the observed trend will be used to evaluate whether higher-ranked pages contain more potential review candidates.

# %% [markdown]
# ## 3. Success metric
#
# *One metric you can defend. What number means 'good'?*

# %% [markdown]
# **Success metric: Precision@50**
#
# I would use Precision@50 because the practical action is to review the highest-priority pages first. The metric measures the proportion of review candidates among the top 50 pages produced by the model. A higher Precision@50 means the model is putting more potential review candidates near the top of the queue. I will report the measured value from the notebook rather than assuming a target performance in advance.

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*

# %%
# !git clone https://github.com/tayyba6/ML_Internship.git
# Out:
# Cloning into 'ML_Internship'...
# remote: Enumerating objects: 114, done.
# remote: Counting objects: 100% (114/114), done.
# remote: Compressing objects: 100% (85/85), done.
# remote: Total 114 (delta 32), reused 78 (delta 13), pack-reused 0 (from 0)
# Receiving objects: 100% (114/114), 1.84 MiB | 13.18 MiB/s, done.
# Resolving deltas: 100% (32/32), done.

# %%
import pandas as pd

df = pd.read_csv("ML_Internship/data/raw/content_refresh_anonymized.csv")

df.head()
# Out:
#              content_id          client_id  search_volume  competition  \
# 0  content_304f48230142  client_f369cb89fc           10.0         0.67
# 1  content_a1fb4e703a9e  client_4e07408562           90.0         0.01
# 2  content_9aa793d4d895  client_7f2253d7e2            0.0         0.00
# 3  content_331d6c4de07b  client_19581e27de           10.0         0.00
# 4  content_d99b7a2d90ca  client_3fdba35f04            0.0         0.00
#
#   competition_level   cpc     content_type    main_intent  word_count  \
# 0              HIGH  2.05  keyword article  transactional      3221.0
# 1               LOW  0.05  keyword article  informational      2481.0
# 2               LOW  0.00  keyword article  informational      3515.0
# 3               LOW  0.00  keyword article     commercial         NaN
# 4               LOW  0.00  keyword article  informational      2803.0
#
#    char_count  ... char_count_tier   ctr  avg_position  engagement_rate  \
# ...

# %% [markdown]
# **Unit of analysis: one row = one pseudonymized content page/item.**
#
# The dataset contains 30,000 rows and 44 columns. Each row represents one content page or item, with information about its search performance, engagement, content characteristics, and trend. For this ranking task, each page is treated as one item that can receive a review-priority score and be placed in a ranked review queue.

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# *What makes the pattern too messy for an if-statement?*

# %% [markdown]
# A fixed rule would rely on one or a small number of manually chosen conditions, but page performance depends on several signals that can interact in different ways. A machine learning model can combine multiple page-level signals and learn patterns from the observed data. This makes it possible to produce a more flexible ranking than a single if-statement, while still evaluating the ranking against a simple baseline.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [x] Every section above is filled — markdown thinking AND the code that backs it
# - [x] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [x] No client names, URLs, or private queries anywhere
# - [x] My claims use careful words: observed, measured, directional, decision-support
# - [x] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
