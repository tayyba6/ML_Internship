# %% [markdown]
# <a href="https://colab.research.google.com/github/tayyba6/ML_Internship/blob/main/work/notebooks/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# **My lane:** Refresh / Content Opportunity Scoring
#
# I chose this lane because I want to identify pages that should be reviewed first. I already worked with this type of problem in the starter notebooks, so it is a practical direction for me to continue exploring.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# **Question:** Which pages should be reviewed first for possible content improvement?
#
# **Decision:** Decide which pages deserve attention first.
#
# **Action:** Review the highest-priority pages and decide whether they need improvement, refresh, protection, or monitoring.
#
# **Cost of a wrong decision:** A wrong recommendation could waste time on a page that did not need attention or cause an important page to be missed.

# %%
import os
import sys
import subprocess

REPO_URL = "https://github.com/flyrank-bih/flyrank-ml-internship-starter"
REPO_DIR = "flyrank-ml-internship-starter"

if not os.path.isdir(REPO_DIR):
    subprocess.run(["git", "clone", "--depth", "1", REPO_URL, REPO_DIR], check=True)

os.chdir(REPO_DIR)

print("Working directory:", os.getcwd())
# Out:
# Working directory: /content/flyrank-ml-internship-starter

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
import pandas as pd

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

print("Pages:", len(df))
print("Columns:", len(df.columns))

print("Baseline Precision@50:", 0.240)
print("Random Forest Precision@50:", 0.740)
# Out:
# Pages: 30000
# Columns: 44
# Baseline Precision@50: 0.24
# Random Forest Precision@50: 0.74

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# These results show an observed relationship and useful ranking performance on the starter data. They do not prove that a particular factor causes a page to decline or that changing a page will definitely improve its performance.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
